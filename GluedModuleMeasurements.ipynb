# %%
#Authorize the API
scope = [
    'https://www.googleapis.com/auth/drive',
    'https://www.googleapis.com/auth/drive.file'
    ]
file_name = 'indigo-muse-308423-829adc108f27.json'
creds = ServiceAccountCredentials.from_json_keyfile_name(file_name,scope)
client = gspread.authorize(creds)

# %%
#Fetch the sheet
import gspread
import pprint
gc = gspread.service_account("indigo-muse-308423-829adc108f27.json")
sheet = gc.open_by_key("1TuGsXDgg0SdahDFKBd9dPFo0fV2Q2wG0BbVTeoSJeJM").get_worksheet(1)
python_sheet = sheet.get_all_records()
pp = pprint.PrettyPrinter()
pp.pprint(python_sheet)
# Out:
# [{'Angle TiltLL': '',
#   'Angle TiltLL RMS': '',
#   'Angle TiltLR': '',
#   'Angle TiltLr RMS': '',
#   'Angle TiltUL': '',
#   'Angle TiltUL RMS': '',
#   'Angle TiltUR': '',
#   'Angle TiltUR RMS': '',
#   'Dist FE_LL_Y': '',
#   'Dist FE_LLtoSensor_X': '',
#   'Dist FE_LR_Y': '',
#   'Dist FE_LRtoSensor_X': '',
#   'Dist FE_Left_DY': '',
#   'Dist FE_Right_DY': '',
#   'Dist FE_UL_Y': '',
#   'Dist FE_ULtoSensor_X': '',
#   'Dist FE_UR_Y': '',
#   'Dist FE_URtoSensor_X': '',
#   'Dist SensorX': '',
#   'Dist SensorY': '',
#   'FE_LL Planarity': 0.025,
#   'FE_LL: Centre Z': 0.522,
#   'FE_LL: Z RMS': 0.005,
#   'FE_LR Planarity': 0.025,
#   'FE_LR: Centre Z': 0.43,
#   'FE_LR: Z RMS': 0.004,
#   'FE_UL Planarity': 0.02,
#   'FE_UL: Centre Z': 0.505,
#   'FE_UL: Z RMS': 0.005,
#   'FE_UR Planarity': 0.023,
#   'FE_UR: Centre Z': 0.43,
#   'FE_UR: Z RMS': 0.004,
#   'Module name': 'quad_rd53a_module4 NoVac',
#   'Sensor Planarity': 0.057,
#   'Sensor: Centre Z': 0.615,
#   'Sensor: Z RMS': 0.016},
#  {'Angle TiltLL': 0.001,
#   'Angle TiltLL RMS': 0.001,
#   'Angle TiltLR': 0.005,
#   'Angle TiltLr RMS': 0.0,
#   'Angle TiltUL': 0.0,
#   'Angle TiltUL RMS': 0.017,
#   'Angle TiltUR': 0.0,
#   'Angle TiltUR RMS': 0.001,
#   'Dist FE_LL_Y': 20.094,
#   'Dist FE_LLtoSensor_X': 1.355,
#   'Dist FE_LR_Y': 20.094,
#   'Dist FE_LRtoSensor_X': 1.366,
#   'Dist FE_Left_DY': 0.101,
#   'Dist FE_Right_DY': 0.104,
#   'Dist FE_UL_Y': 20.093,
#   'Dist FE_ULtoSensor_X': 1.362,
#   'Dist FE_UR_Y': 20.093,
#   'Dist FE_URtoSensor_X': 1.36,
#   'Dist SensorX': 39.446,
#   'Dist SensorY': 41.049,
#   'FE_LL Planarity': 0.024,
#   'FE_LL: Centre Z': 0.408,
#   'FE_LL: Z RMS': 0.005,
#   'FE_LR Planarity': 0.023,
#   'FE_LR: Centre Z': 0.407,
#   'FE_LR: Z RMS': 0.004,
#   'FE_UL Planarity': 0.021,
#   'FE_UL: Centre Z': 0.402,
#   'FE_UL: Z RMS': 0.005,
#   'FE_UR Planarity': 0.027,
#   'FE_UR: Centre Z': 0.404,
#   'FE_UR: Z RMS': 0.005,
#   'Module name': 'quad_rd53a_module4Vac',
#   'Sensor Planarity': 0.026,
#   'Sensor: Centre Z': 0.567,
#   'Sensor: Z RMS': 0.005},
#  {'Angle TiltLL': '',
#   'Angle TiltLL RMS': '',
#   'Angle TiltLR': '',
#   'Angle TiltLr RMS': '',
#   'Angle TiltUL': '',
#   'Angle TiltUL RMS': '',
#   'Angle TiltUR': '',
#   'Angle TiltUR RMS': '',
#   'Dist FE_LL_Y': '',
#   'Dist FE_LLtoSensor_X': '',
#   'Dist FE_LR_Y': '',
#   'Dist FE_LRtoSensor_X': '',
#   'Dist FE_Left_DY': '',
#   'Dist FE_Right_DY': '',
#   'Dist FE_UL_Y': '',
#   'Dist FE_ULtoSensor_X': '',
#   'Dist FE_UR_Y': '',
#   'Dist FE_URtoSensor_X': '',
#   'Dist SensorX': '',
#   'Dist SensorY': '',
#   'FE_LL Planarity': 0.024,
#   'FE_LL: Centre Z': 0.434,
#   'FE_LL: Z RMS': 0.005,
#   'FE_LR Planarity': 0.022,
#   'FE_LR: Centre Z': 0.497,
#   'FE_LR: Z RMS': 0.004,
#   'FE_UL Planarity': 0.025,
#   'FE_UL: Centre Z': 0.417,
#   'FE_UL: Z RMS': 0.005,
#   'FE_UR Planarity': 0.02,
#   'FE_UR: Centre Z': 0.497,
#   'FE_UR: Z RMS': 0.004,
#   'Module name': 'quad_rd53a_module5 NoVac',
#   'Sensor Planarity': 0.051,
#   'Sensor: Centre Z': 0.602,
#   'Sensor: Z RMS': 0.015},
#  {'Angle TiltLL': -0.004,
#   'Angle TiltLL RMS': 0.001,
#   'Angle TiltLR': -0.001,
#   'Angle TiltLr RMS': 0.001,
#   'Angle TiltUL': 0.003,
#   'Angle TiltUL RMS': 0.001,
#   'Angle TiltUR': -0.003,
#   'Angle TiltUR RMS': 0.001,
#   'Dist FE_LL_Y': 20.094,
#   'Dist FE_LLtoSensor_X': 1.36,
#   'Dist FE_LR_Y': 20.094,
#   'Dist FE_LRtoSensor_X': 1.362,
#   'Dist FE_Left_DY': 0.104,
#   'Dist FE_Right_DY': 0.103,
#   'Dist FE_UL_Y': 20.093,
#   'Dist FE_ULtoSensor_X': 1.365,
#   'Dist FE_UR_Y': 20.093,
#   'Dist FE_URtoSensor_X': 1.359,
#   'Dist SensorX': 39.446,
#   'Dist SensorY': 41.048,
#   'FE_LL Planarity': 0.025,
#   'FE_LL: Centre Z': 0.402,
#   'FE_LL: Z RMS': 0.005,
#   'FE_LR Planarity': 0.023,
#   'FE_LR: Centre Z': 0.401,
#   'FE_LR: Z RMS': 0.004,
#   'FE_UL Planarity': 0.024,
#   'FE_UL: Centre Z': 0.398,
#   'FE_UL: Z RMS': 0.005,
#   'FE_UR Planarity': 0.024,
#   'FE_UR: Centre Z': 0.398,
#   'FE_UR: Z RMS': 0.004,
#   'Module name': 'quad_rd53a_module5Vac',
#   'Sensor Planarity': 0.044,
#   'Sensor: Centre Z': 0.561,
#   'Sensor: Z RMS': 0.005},
#  {'Angle TiltLL': '',
#   'Angle TiltLL RMS': '',
#   'Angle TiltLR': '',
#   'Angle TiltLr RMS': '',
#   'Angle TiltUL': '',
#   'Angle TiltUL RMS': '',
#   'Angle TiltUR': '',
#   'Angle TiltUR RMS': '',
#   'Dist FE_LL_Y': '',
#   'Dist FE_LLtoSensor_X': '',
#   'Dist FE_LR_Y': '',
#   'Dist FE_LRtoSensor_X': '',
#   'Dist FE_Left_DY': '',
#   'Dist FE_Right_DY': '',
#   'Dist FE_UL_Y': '',
#   'Dist FE_ULtoSensor_X': '',
#   'Dist FE_UR_Y': '',
#   'Dist FE_URtoSensor_X': '',
#   'Dist SensorX': '',
#   'Dist SensorY': '',
#   'FE_LL Planarity': 0.027,
#   'FE_LL: Centre Z': 0.495,
#   'FE_LL: Z RMS': 0.005,
#   'FE_LR Planarity': 0.021,
#   'FE_LR: Centre Z': 0.446,
#   'FE_LR: Z RMS': 0.004,
#   'FE_UL Planarity': 0.027,
#   'FE_UL: Centre Z': 0.477,
#   'FE_UL: Z RMS': 0.005,
#   'FE_UR Planarity': 0.023,
#   'FE_UR: Centre Z': 0.443,
#   'FE_UR: Z RMS': 0.004,
#   'Module name': 'quad_rd53a_module7 NoVac',
#   'Sensor Planarity': 0.05,
#   'Sensor: Centre Z': 0.606,
#   'Sensor: Z RMS': 0.015},
#  {'Angle TiltLL': -0.006,
#   'Angle TiltLL RMS': 0.001,
#   'Angle TiltLR': 0.002,
#   'Angle TiltLr RMS': 0.001,
#   'Angle TiltUL': 0.002,
#   'Angle TiltUL RMS': 0.0,
#   'Angle TiltUR': 0.033,
#   'Angle TiltUR RMS': 0.004,
#   'Dist FE_LL_Y': 20.094,
#   'Dist FE_LLtoSensor_X': 1.362,
#   'Dist FE_LR_Y': 20.094,
#   'Dist FE_LRtoSensor_X': 1.363,
#   'Dist FE_Left_DY': 0.105,
#   'Dist FE_Right_DY': 0.1,
#   'Dist FE_UL_Y': 20.093,
#   'Dist FE_ULtoSensor_X': 1.367,
#   'Dist FE_UR_Y': 20.093,
#   'Dist FE_URtoSensor_X': 1.352,
#   'Dist SensorX': 39.445,
#   'Dist SensorY': 41.049,
#   'FE_LL Planarity': 0.027,
#   'FE_LL: Centre Z': 0.405,
#   'FE_LL: Z RMS': 0.005,
#   'FE_LR Planarity': 0.021,
#   'FE_LR: Centre Z': 0.403,
#   'FE_LR: Z RMS': 0.004,
#   'FE_UL Planarity': 0.027,
#   'FE_UL: Centre Z': 0.402,
#   'FE_UL: Z RMS': 0.005,
#   'FE_UR Planarity': 0.028,
#   'FE_UR: Centre Z': 0.401,
#   'FE_UR: Z RMS': 0.005,
#   'Module name': 'quad_rd53a_module7Vac',
#   'Sensor Planarity': 0.029,
#   'Sensor: Centre Z': 0.564,
#   'Sensor: Z RMS': 0.005},
#  {'Angle TiltLL': '',
#   'Angle TiltLL RMS': '',
#   'Angle TiltLR': '',
#   'Angle TiltLr RMS': '',
#   'Angle TiltUL': '',
#   'Angle TiltUL RMS': '',
#   'Angle TiltUR': '',
#   'Angle TiltUR RMS': '',
#   'Dist FE_LL_Y': '',
#   'Dist FE_LLtoSensor_X': '',
#   'Dist FE_LR_Y': '',
#   'Dist FE_LRtoSensor_X': '',
#   'Dist FE_Left_DY': '',
#   'Dist FE_Right_DY': '',
#   'Dist FE_UL_Y': '',
#   'Dist FE_ULtoSensor_X': '',
#   'Dist FE_UR_Y': '',
#   'Dist FE_URtoSensor_X': '',
#   'Dist SensorX': '',
#   'Dist SensorY': '',
#   'FE_LL Planarity': 0.023,
#   'FE_LL: Centre Z': 0.419,
#   'FE_LL: Z RMS': 0.005,
#   'FE_LR Planarity': 0.023,
#   'FE_LR: Centre Z': 0.496,
#   'FE_LR: Z RMS': 0.004,
#   'FE_UL Planarity': 0.022,
#   'FE_UL: Centre Z': 0.407,
#   'FE_UL: Z RMS': 0.005,
#   'FE_UR Planarity': 0.02,
#   'FE_UR: Centre Z': 0.495,
#   'FE_UR: Z RMS': 0.004,
#   'Module name': 'quad_rd53a_module6 NoVac',
#   'Sensor Planarity': 0.048,
#   'Sensor: Centre Z': 0.598,
#   'Sensor: Z RMS': 0.014},
#  {'Angle TiltLL': -0.002,
#   'Angle TiltLL RMS': 0.001,
#   'Angle TiltLR': -0.001,
#   'Angle TiltLr RMS': 0.001,
#   'Angle TiltUL': 0.004,
#   'Angle TiltUL RMS': 0.001,
#   'Angle TiltUR': -0.003,
#   'Angle TiltUR RMS': 0.001,
#   'Dist FE_LL_Y': 20.092,
#   'Dist FE_LLtoSensor_X': 1.364,
#   'Dist FE_LR_Y': 20.093,
#   'Dist FE_LRtoSensor_X': 1.362,
#   'Dist FE_Left_DY': 0.103,
#   'Dist FE_Right_DY': 0.103,
#   'Dist FE_UL_Y': 20.093,
#   'Dist FE_ULtoSensor_X': 1.366,
#   'Dist FE_UR_Y': 20.091,
#   'Dist FE_URtoSensor_X': 1.358,
#   'Dist SensorX': 39.446,
#   'Dist SensorY': 41.048,
#   'FE_LL Planarity': 0.024,
#   'FE_LL: Centre Z': 0.401,
#   'FE_LL: Z RMS': 0.005,
#   'FE_LR Planarity': 0.022,
#   'FE_LR: Centre Z': 0.4,
#   'FE_LR: Z RMS': 0.004,
#   'FE_UL Planarity': 0.022,
#   'FE_UL: Centre Z': 0.398,
#   'FE_UL: Z RMS': 0.005,
#   'FE_UR Planarity': 0.024,
#   'FE_UR: Centre Z': 0.397,
#   'FE_UR: Z RMS': 0.004,
#   'Module name': 'quad_rd53a_module6Vac',
#   'Sensor Planarity': 0.03,
#   'Sensor: Centre Z': 0.561,
#   'Sensor: Z RMS': 0.005},
#  {'Angle TiltLL': '',
#   'Angle TiltLL RMS': '',
#   'Angle TiltLR': '',
#   'Angle TiltLr RMS': '',
#   'Angle TiltUL': '',
#   'Angle TiltUL RMS': '',
#   'Angle TiltUR': '',
#   'Angle TiltUR RMS': '',
#   'Dist FE_LL_Y': '',
#   'Dist FE_LLtoSensor_X': '',
#   'Dist FE_LR_Y': '',
#   'Dist FE_LRtoSensor_X': '',
#   'Dist FE_Left_DY': '',
#   'Dist FE_Right_DY': '',
#   'Dist FE_UL_Y': '',
#   'Dist FE_ULtoSensor_X': '',
#   'Dist FE_UR_Y': '',
#   'Dist FE_URtoSensor_X': '',
#   'Dist SensorX': '',
#   'Dist SensorY': '',
#   'FE_LL Planarity': 0.023,
#   'FE_LL: Centre Z': 0.507,
#   'FE_LL: Z RMS': 0.005,
#   'FE_LR Planarity': 0.021,
#   'FE_LR: Centre Z': 0.437,
#   'FE_LR: Z RMS': 0.004,
#   'FE_UL Planarity': 0.026,
#   'FE_UL: Centre Z': 0.491,
#   'FE_UL: Z RMS': 0.005,
#   'FE_UR Planarity': 0.02,
#   'FE_UR: Centre Z': 0.432,
#   'FE_UR: Z RMS': 0.004,
#   'Module name': 'quad_rd53a_module8 NoVac',
#   'Sensor Planarity': 0.056,
#   'Sensor: Centre Z': 0.607,
#   'Sensor: Z RMS': 0.016},
#  {'Angle TiltLL': 0.001,
#   'Angle TiltLL RMS': 0.001,
#   'Angle TiltLR': 0.003,
#   'Angle TiltLr RMS': 0.001,
#   'Angle TiltUL': 0.002,
#   'Angle TiltUL RMS': 0.001,
#   'Angle TiltUR': 0.002,
#   'Angle TiltUR RMS': 0.001,
#   'Dist FE_LL_Y': 20.094,
#   'Dist FE_LLtoSensor_X': 1.362,
#   'Dist FE_LR_Y': 20.093,
#   'Dist FE_LRtoSensor_X': 1.365,
#   'Dist FE_Left_DY': 0.102,
#   'Dist FE_Right_DY': 0.102,
#   'Dist FE_UL_Y': 20.094,
#   'Dist FE_ULtoSensor_X': 1.366,
#   'Dist FE_UR_Y': 20.093,
#   'Dist FE_URtoSensor_X': 1.361,
#   'Dist SensorX': 39.445,
#   'Dist SensorY': 41.046,
#   'FE_LL Planarity': 0.024,
#   'FE_LL: Centre Z': 0.404,
#   'FE_LL: Z RMS': 0.005,
#   'FE_LR Planarity': 0.021,
#   'FE_LR: Centre Z': 0.404,
#   'FE_LR: Z RMS': 0.004,
#   'FE_UL Planarity': 0.025,
#   'FE_UL: Centre Z': 0.401,
#   'FE_UL: Z RMS': 0.005,
#   'FE_UR Planarity': 0.026,
#   'FE_UR: Centre Z': 0.399,
#   'FE_UR: Z RMS': 0.005,
#   'Module name': 'quad_rd53a_module8Vac',
#   'Sensor Planarity': 0.026,
#   'Sensor: Centre Z': 0.563,
#   'Sensor: Z RMS': 0.004}]

# %%
import glob
files = glob.glob("mm_outputs/hz_what.txt")

# %%
def trim_data(data):
    trimmed_data = []
    for el in data:
        if el[0][0] == '"' and "Points 3D RM" not in el[0]:
            trimmed_data.append(el)
    return trimmed_data

def trim_filename(filename):
    fn = filename
    fn = fn.split("/")
    fn = fn[1].split(".")
    fn = fn[0]
    return fn

def sort_vac_novac(tdata):
    vac_rows = []
    novac_rows = []
    for el in tdata:
        if "NoVac" in el[0]:
            novac_rows.append(el)
        else:
            vac_rows.append(el)
    return vac_rows, novac_rows

def get_novac_row(novac_data):
    novac_row = []
    novac_values = [0,2,1]
    for k in range (0,4):
        for el in novac_values:
            novac_row.append(novac_data[el+k*len(novac_values)])
    return novac_row


def get_distances(in_vac_data):
    distance_values = []
    for el in in_vac_data:
        if "Distance" in el[0] or "Angle"in el[0] :
            distance_values.append(el)
    return distance_values

# %%
column_names = ["Module name","FE_LL: Centre Z","FE_LL: Z RMS", "FE_LL Planarity", 
               "FE_UL: Centre Z","FE_UL: Z RMS", "FE_UL Planarity", 
               "FE_LR: Centre Z","FE_LR: Z RMS", "FE_LR Planarity", 
               "FE_UR: Centre Z","FE_UR: Z RMS", "FE_UR Planarity", 
               ]
print (len(column_names))
# Out:
# 13

# %%
import csv
import statistics
#sheet.append_row(column_names)

for filename in files:
    print (filename)
    with open(filename, newline='', encoding='ISO-8859-1') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
        data = []
        novac_row = []
        vac_row = []
        for row in spamreader:
            data.append(row)
        vac_data, novac_data = sort_vac_novac(trim_data(data))
        novac_row.append("Module7_Glued"+" NoVac")
        for el in get_novac_row(novac_data):
            novac_row.append(el[1])
        vac_row.append("Module7_Glued"+"Vac")
        for el in get_novac_row(vac_data):
            vac_row.append(el[1])
        print (novac_row)
        print (vac_row)
        sheet.append_row(novac_row)
        sheet.append_row(vac_row)
# Out:
# mm_outputs/hz_what.txt
# ['Module7_Glued NoVac', '0.420', '0.004', '0.033', '0.408', '0.005', '0.043', '0.416', '0.004', '0.026', '0.414', '0.004', '0.026']
# ['Module7_GluedVac', '0.395', '0.004', '0.033', '0.391', '0.005', '0.044', '0.392', '0.004', '0.027', '0.390', '0.004', '0.029']
